# %%
from jina import Flow

# %%
Flow.load_config('../../src/semantic_search_qa/server/server.yml').plot()
# Out:
# ]8;id=913455;https://mermaid....\Click here to see the visualization in browser]8;;\
# <img src="https://mermaid...."/>
